# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mobin\downloads\ananconda\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mobin\downloads\ananconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mobin\downloads\ananconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# data
x = [1,2,3,4,5,6]
y = [1,2,3,6,7,8]

# Plot graph
plt.plot(x,y)

# label
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("simple line graph")

plt.show()

# %%
import matplotlib.pyplot as plt

# data
X = [0,10,20,30,40,50]
y = [1,2,10,4,5,6]

# plot graph
plt.plot(x,y)

# label
plt.xlabel("X-axis")
plt.ylabel("Y-axias")
plt.title("GRAPH")

plt.show()

# %%
import matplotlib.pyplot as plt

group1 = [1,2,3,4,5]
group2 = [10,20,30,40,50]

plt.plot(group1,group2)
# label
plt.xlabel('Group 1')
plt.ylabel('Group 2')
plt.title('GROUP')

plt.show()
